# %%
import trk_to_hist
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
plt.matplotlib.rcParams['figure.figsize']=(20,14)
plt.matplotlib.rcParams['font.size']=16

# %%
os.getcwd()
# Out:
# '/home/zookeeper/Desktop/workdir'

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.16/workdirshort')

# %%
os.listdir()
# Out:
# ['m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..trk',
#  'm2000LHS16.TRUE.LdeBoer17.FALSE.LBlouin20.FALSE..short',
#  'm2000LHS16.TRUE.LdeBoer17.TRUE.LBlouin20.FALSE.iso',
#  'm2000LHS16.FALSE.LdeBoer17.TRUE.LBlouin20.FALSE.iso',
#  'm2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE.iso',
#  'm2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..short',
#  'm2000LHS16.FALSE.LdeBoer17.TRUE.LBlouin20.FALSE..short',
#  'm2000LHS16.TRUE.LdeBoer17.FALSE.LBlouin20.FALSE.iso',
#  'm2000LHS16.TRUE.LdeBoer17.TRUE.LBlouin20.FALSE..short',
#  'm2000LHS16.TRUE.LdeBoer17.FALSE.LBlouin20.FALSE..trk',
#  'm2000LHS16.FALSE.LdeBoer17.TRUE.LBlouin20.FALSE..trk',
#  'm2000LHS16.TRUE.LdeBoer17.TRUE.LBlouin20.FALSE..trk']

# %%
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
dp = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLdeBoer17 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16LdeBoer17 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')

# %%
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16LdeBoer17')
plt.legend();

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['AGE'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LHS16LdeBoer17')
plt.legend();

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.16/workdirshort1')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
dp = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLdeBoer17 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16LdeBoer17 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')

# %%
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16LdeBoer17')
plt.legend();

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['AGE'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LHS16LdeBoer17')
plt.legend();

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.16/workdirshort2')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
dp = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLdeBoer17 = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')

# %%
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.legend();

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['AGE'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.legend();

# %%
dp = pd.read_csv('m1100LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16 = pd.read_csv('m1100LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLdeBoer17 = pd.read_csv('m1100LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')

# %%
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.legend();

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['AGE'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.legend();

# %%
os.chdir('/home/zookeeper/Desktop/workdir/workdirshort')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
dp = pd.read_csv('m2000LHS16.FALSE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLHS16 = pd.read_csv('m2000LHS16.TRUE.LdeBoer17.FALSE.LBlouin20.FALSE..csv')
dpLdeBoer17 = pd.read_csv('m2000LHS16.TRUE.LdeBoer17.TRUE.LBlouin20.FALSE..csv')

# %%
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='both')
plt.legend();

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],label='Orginial')
plt.plot(dpLHS16['AGE'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.legend();

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='Original')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='Both')
plt.legend();

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
plt.plot(dp['log(Teff)'].values,dp['log(L/Lsun)'],label='Original')
plt.plot(dpLHS16['log(Teff)'].values,dp['log(L/Lsun)'],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values,dp['log(L/Lsun)'],label='Both')
plt.legend();

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
plt.plot(dp['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='Original')
plt.plot(dpLHS16['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='LHS16')
plt.plot(dpLdeBoer17['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='Both')
plt.legend()
plt.xlim(2.19,2.23)
plt.ylim(0,0.1e36);

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
plt.plot(dp['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='Original')
plt.plot(dpLHS16['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='LHS16')
plt.plot(dpLdeBoer17['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],label='Both')
plt.legend()
plt.xlim(3.1,3.11);

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
plt.plot(dp['AGE'].values,dp['Luminosity: triple-alpha'],label='Original')
plt.plot(dpLHS16['AGE'].values,dp['Luminosity: triple-alpha'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['Luminosity: triple-alpha'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values,dp['Luminosity: triple-alpha'],label='Both')
plt.legend()
plt.xlim(0.478,0.4795);

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')

os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
plt.plot(dp['AGE'].values,dp['Luminosity: triple-alpha'],'b--',label='Original')
plt.plot(dpLHS16['AGE'].values,dp['Luminosity: triple-alpha'],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values,dp['Luminosity: triple-alpha'],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values,dp['Luminosity: triple-alpha'],'g--',label='Both')
plt.legend()
plt.xlim(1.0789,1.079)
plt.ylim(1.8e32,2.7e32)
plt.xlabel('Age after Helium flash')
plt.ylabel('Triple-alpha luminosity');

# %%
log(L/Lsun)

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e34 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e34 and i < len(dp):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e34 and i < len(dp):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e34 and i < len(dp):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hflash:] - hflashtime,dp['log(L/Lsun)'].values[hflash:],label='Original')
plt.plot(dpLHS16['AGE'].values[hflashLHS16:] - hflashtimeLHS16,dp['log(L/Lsun)'].values[hflashLHS16:],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hflashLdeBoer17:] - hflashtimeLdeBoer17,dp['log(L/Lsun)'].values[hflashLdeBoer17:],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hflashLHS16LdeBoer17:] - hflashtimeLHS16LdeBoer17,dp['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],label='Both')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Log(L/Lsun)');

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hflash:] - hflashtime,dp['log(L/Lsun)'].values[hflash:],label='Original')
plt.plot(dpLHS16['AGE'].values[hflashLHS16:] - hflashtimeLHS16,dp['log(L/Lsun)'].values[hflashLHS16:],label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hflashLdeBoer17:] - hflashtimeLdeBoer17,dp['log(L/Lsun)'].values[hflashLdeBoer17:],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hflashLHS16LdeBoer17:] - hflashtimeLHS16LdeBoer17,dp['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],label='Both')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Log(L/Lsun)');

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hflash:] - hflashtime,dp['log(L/Lsun)'].values[hflash:],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hflashLHS16:] - hflashtimeLHS16,dp['log(L/Lsun)'].values[hflashLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hflashLdeBoer17:] - hflashtimeLdeBoer17,dp['log(L/Lsun)'].values[hflashLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hflashLHS16LdeBoer17:] - hflashtimeLHS16LdeBoer17,dp['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium flash (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['log(Teff)'].values[hflash:],dp['log(L/Lsun)'].values[hflash:],label='Original')
plt.plot(dpLHS16['log(Teff)'].values[hflashLHS16:],dp['log(L/Lsun)'].values[hflashLHS16:],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values[hflashLdeBoer17:],dp['log(L/Lsun)'].values[hflashLdeBoer17:],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values[hflashLHS16LdeBoer17:],dp['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],label='Both')
plt.legend()
plt.xlabel('Log(T_eff)')
plt.ylabel('Log(L/Lsun)');

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdir')
dp = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16')
dpLHS16 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.21/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m2000feh-2.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['log(Teff)'].values[hflash:],dp['log(L/Lsun)'].values[hflash:],label='Original')
plt.plot(dpLHS16['log(Teff)'].values[hflashLHS16:],dp['log(L/Lsun)'].values[hflashLHS16:],label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values[hflashLdeBoer17:],dp['log(L/Lsun)'].values[hflashLdeBoer17:],label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values[hflashLHS16LdeBoer17:],dp['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],label='Both')
plt.legend()
plt.xlabel('Log(T_eff)')
plt.ylabel('Log(L/Lsun)');

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Central: Z'].values[i] < 1 and i < len(dp):
    i += 1
hend = i
hendtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Central: Z'].values[i] < 1 and i < len(dpLHS16):
    i += 1
hendLHS16 = i
hendtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLdeBoer17):
    i += 1
hendLdeBoer17 = i
hendtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLHS16LdeBoer17):
    i += 1
hendLHS16LdeBoer17 = i
hendtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hend:] - hendtime,dp['log(L/Lsun)'].values[hend:],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hendLHS16:] - hendtimeLHS16,dpLHS16['log(L/Lsun)'].values[hendLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hendLdeBoer17:] - hendtimeLdeBoer17,dpLdeBoer17['log(L/Lsun)'].values[hendLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hendLHS16LdeBoer17:] - hendtimeLHS16LdeBoer17,dpLHS16LdeBoer17['log(L/Lsun)'].values[hendLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning ends (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Central: Z'].values[i] < 1 and i < len(dp):
    i += 1
hend = i
hendtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Central: Z'].values[i] < 1 and i < len(dpLHS16):
    i += 1
hendLHS16 = i
hendtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLdeBoer17):
    i += 1
hendLdeBoer17 = i
hendtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLHS16LdeBoer17):
    i += 1
hendLHS16LdeBoer17 = i
hendtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hend:] - hendtime,dp['log(L/Lsun)'].values[hend:],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hendLHS16:] - hendtimeLHS16,dpLHS16['log(L/Lsun)'].values[hendLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hendLdeBoer17:] - hendtimeLdeBoer17,dpLdeBoer17['log(L/Lsun)'].values[hendLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hendLHS16LdeBoer17:] - hendtimeLHS16LdeBoer17,dpLHS16LdeBoer17['log(L/Lsun)'].values[hendLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning ends (Gyr)')
plt.ylabel('Log(L/Lsun)')
plt.xlim(0.01,0.015)
plt.ylim(2.4,2.9);

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Central: Z'].values[i] < 1 and i < len(dp):
    i += 1
hend = i
hendtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Central: Z'].values[i] < 1 and i < len(dpLHS16):
    i += 1
hendLHS16 = i
hendtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLdeBoer17):
    i += 1
hendLdeBoer17 = i
hendtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLHS16LdeBoer17):
    i += 1
hendLHS16LdeBoer17 = i
hendtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dpLHS16):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dpLdeBoer17):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dpLHS16LdeBoer17):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hflash:hend] - hflashtime,dp['log(L/Lsun)'].values[hflash:hend],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hflashLHS16:hendLHS16] - hflashtimeLHS16,dpLHS16['log(L/Lsun)'].values[hflashLHS16:hendLHS16],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hflashLdeBoer17:hendLdeBoer17] - hflashtimeLdeBoer17,dpLdeBoer17['log(L/Lsun)'].values[hflashLdeBoer17:hendLdeBoer17],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hflashLHS16LdeBoer17:hendLHS16LdeBoer17] - hflashtimeLHS16LdeBoer17,dpLHS16LdeBoer17['log(L/Lsun)'].values[hflashLHS16LdeBoer17:hendLHS16LdeBoer17],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning begins (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],'b-',label='Original')
plt.plot(dpLHS16['AGE'],dpLHS16['log(L/Lsun)'],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'],dpLdeBoer17['log(L/Lsun)'],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'],dpLHS16LdeBoer17['log(L/Lsun)'],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning begins (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
plt.plot(dp['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],'b-',label='Original')
plt.plot(dpLHS16['log(L/Lsun)'],dpLHS16['Luminosity: triple-alpha'],'r--',label='LHS16')
plt.plot(dpLdeBoer17['log(L/Lsun)'],dpLdeBoer17['Luminosity: triple-alpha'],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(L/Lsun)'],dpLHS16LdeBoer17['Luminosity: triple-alpha'],'g-',label='Both')
plt.legend()
plt.xlabel('log(L/Lsun)')
plt.ylabel('Luminosity: triple-alpha')
plt.xlim(2.8,3.2)
plt.ylim(3e36)
# Out:
# (3e+36, 5.0571273795000005e+36)

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dp['Central: X'].values[i] - dp['Central: Z'].values[i] >= 1e-4 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dpLHS16['Central: X'].values[i] - dpLHS16['Central: Z'].values[i] >= 1e-4 and i < len(dpLHS16):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dpLdeBoer17['Central: X'].values[i] - dpLdeBoer17['Central: Z'].values[i] >= 1e-4 and i < len(dpLdeBoer17):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dpLHS16LdeBoer17['Central: X'].values[i] - dpLHS16LdeBoer17['Central: Z'].values[i] >= 1e-4 and i < len(dpLHS16LdeBoer17):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['log(Teff)'].values[hflash:],dp['log(L/Lsun)'].values[hflash:],'b-',label='Original')
plt.plot(dpLHS16['log(Teff)'].values[hflashLHS16:],dpLHS16['log(L/Lsun)'].values[hflashLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values[hflashLdeBoer17:],dpLdeBoer17['log(L/Lsun)'].values[hflashLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values[hflashLHS16LdeBoer17:],dpLHS16LdeBoer17['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Log(T_eff)')
plt.ylabel('Log(L/Lsun)');

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['log(Teff)'].values[hflash:],dp['log(L/Lsun)'].values[hflash:],'b-',label='Original')
plt.plot(dpLHS16['log(Teff)'].values[hflashLHS16:],dpLHS16['log(L/Lsun)'].values[hflashLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['log(Teff)'].values[hflashLdeBoer17:],dpLdeBoer17['log(L/Lsun)'].values[hflashLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['log(Teff)'].values[hflashLHS16LdeBoer17:],dpLHS16LdeBoer17['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Log(T_eff)')
plt.ylabel('Log(L/Lsun)');

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdir')
dp = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dp['Central: X'].values[i] - dp['Central: Z'].values[i] >= 1e-4 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dpLHS16['Central: X'].values[i] - dpLHS16['Central: Z'].values[i] >= 1e-4 and i < len(dpLHS16):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dpLdeBoer17['Central: X'].values[i] - dpLdeBoer17['Central: Z'].values[i] >= 1e-4 and i < len(dpLdeBoer17):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.22/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh0.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while 1 - dpLHS16LdeBoer17['Central: X'].values[i] - dpLHS16LdeBoer17['Central: Z'].values[i] >= 1e-4 and i < len(dpLHS16LdeBoer17):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hflash:] - hflashtime,dp['log(L/Lsun)'].values[hflash:],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hflashLHS16:] - hflashtimeLHS16,dp['log(L/Lsun)'].values[hflashLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hflashLdeBoer17:] - hflashtimeLdeBoer17,dpLdeBoer17['log(L/Lsun)'].values[hflashLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hflashLHS16LdeBoer17:] - hflashtimeLHS16LdeBoer17,dpLHS16LdeBoer17['log(L/Lsun)'].values[hflashLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning ends (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdir')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16LdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdir')
dp = pd.read_csv('m3000feh-1.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dp['Central: Z'].values[i] < 1 and i < len(dp):
    i += 1
hend = i
hendtime = dp['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16')
dpLHS16 = pd.read_csv('m3000feh-1.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16['Central: Z'].values[i] < 1 and i < len(dpLHS16):
    i += 1
hendLHS16 = i
hendtimeLHS16 = dpLHS16['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m3000feh-1.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLdeBoer17):
    i += 1
hendLdeBoer17 = i
hendtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m3000feh-1.0afe0.0ML1.9310ovs0.0pp1.0.csv')
i = 0
while dpLHS16LdeBoer17['Central: Z'].values[i] < 1 and i < len(dpLHS16LdeBoer17):
    i += 1
hendLHS16LdeBoer17 = i
hendtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
i = 0
while dp['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dp):
    i += 1
hflash = i
hflashtime = dp['AGE'].values[i]
i = 0
while dpLHS16['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dpLHS16):
    i += 1
hflashLHS16 = i
hflashtimeLHS16 = dpLHS16['AGE'].values[i]
i = 0
while dpLdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dpLdeBoer17):
    i += 1
hflashLdeBoer17 = i
hflashtimeLdeBoer17 = dpLdeBoer17['AGE'].values[i]
i = 0
while dpLHS16LdeBoer17['Luminosity: triple-alpha'].values[i] <= 1e30 and i < len(dpLHS16LdeBoer17):
    i += 1
hflashLHS16LdeBoer17 = i
hflashtimeLHS16LdeBoer17 = dpLHS16LdeBoer17['AGE'].values[i]
plt.plot(dp['AGE'].values[hflash:hend] - hflashtime,dp['log(L/Lsun)'].values[hflash:hend],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hflashLHS16:hendLHS16] - hflashtimeLHS16,dpLHS16['log(L/Lsun)'].values[hflashLHS16:hendLHS16],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hflashLdeBoer17:hendLdeBoer17] - hflashtimeLdeBoer17,dpLdeBoer17['log(L/Lsun)'].values[hflashLdeBoer17:hendLdeBoer17],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hflashLHS16LdeBoer17:hendLHS16LdeBoer17] - hflashtimeLHS16LdeBoer17,dpLHS16LdeBoer17['log(L/Lsun)'].values[hflashLHS16LdeBoer17:hendLHS16LdeBoer17],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning begins (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
plt.plot(dp['AGE'].values,dp['log(L/Lsun)'],'b-',label='Original')
plt.plot(dpLHS16['AGE'],dpLHS16['log(L/Lsun)'],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'],dpLdeBoer17['log(L/Lsun)'],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'],dpLHS16LdeBoer17['log(L/Lsun)'],'g-',label='Both')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Log(L/Lsun)');

# %%
plt.plot(dp['AGE'].values[hend:] - hendtime,dp['log(L/Lsun)'].values[hend:],'b-',label='Original')
plt.plot(dpLHS16['AGE'].values[hendLHS16:] - hendtimeLHS16,dpLHS16['log(L/Lsun)'].values[hendLHS16:],'r--',label='LHS16')
plt.plot(dpLdeBoer17['AGE'].values[hendLdeBoer17:] - hendtimeLdeBoer17,dpLdeBoer17['log(L/Lsun)'].values[hendLdeBoer17:],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['AGE'].values[hendLHS16LdeBoer17:] - hendtimeLHS16LdeBoer17,dpLHS16LdeBoer17['log(L/Lsun)'].values[hendLHS16LdeBoer17:],'g-',label='Both')
plt.legend()
plt.xlabel('Time after Helium burning ends (Gyr)')
plt.ylabel('Log(L/Lsun)');

# %%
plt.plot(dp['Central: log(T)'].values,dp['Luminosity: triple-alpha'],'b-',label='Original')
plt.plot(dpLHS16['Central: log(T)'],dpLHS16['Luminosity: triple-alpha'],'r--',label='LHS16')
plt.plot(dpLdeBoer17['Central: log(T)'],dpLdeBoer17['Luminosity: triple-alpha'],'y--',label='LdeBoer17')
plt.plot(dpLHS16LdeBoer17['Central: log(T)'],dpLHS16LdeBoer17['Luminosity: triple-alpha'],'g-',label='Both')
plt.legend()
plt.xlabel('Central: log(T)')
plt.ylabel('Luminosity: triple-alpha')
plt.xlim(8);

# %%
plt.plot(dp['AGE'].values,dp['Luminosity: triple-alpha'],'b-',label='Original')
plt.plot(dpLHS16['AGE'],dpLHS16['Luminosity: triple-alpha'],'r--',label='LHS16')
plt.legend()
plt.xlabel('AGE')
plt.ylabel('Luminosity: triple-alpha')
plt.xlim(0.22);

# %%
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdir')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16LdeBoer17')
for file in os.listdir():
    if file[-4:] == '.trk':
        trk_to_hist.convert(file)

# %%
plt.matplotlib.rcParams['figure.figsize'] = (20,20)
plt.matplotlib.rcParams['font.size'] = 25
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdir')
dp = pd.read_csv('m0700feh-1.6afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16')
dpLHS16 = pd.read_csv('m0700feh-1.6afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLdeBoer17')
dpLdeBoer17 = pd.read_csv('m0700feh-1.6afe0.0ML1.9310ovs0.0pp1.0.csv')
os.chdir('/home/zookeeper/Desktop/workdir/9.27/workdirLHS16LdeBoer17')
dpLHS16LdeBoer17 = pd.read_csv('m0700feh-1.6afe0.0ML1.9310ovs0.0pp1.0.csv')

# %%
plt.plot(dp['AGE'].values,dp['Luminosity: triple-alpha'],'b-',label='Original')
plt.plot(dpLHS16['AGE'],dpLHS16['Luminosity: triple-alpha'],'r--',label='LHS16')
#plt.plot(dpLdeBoer17['AGE'],dpLdeBoer17['Luminosity: triple-alpha'],'y--',label='LdeBoer17')
#plt.plot(dpLHS16LdeBoer17['AGE'],dpLHS16LdeBoer17['Luminosity: triple-alpha'],'g-',label='Both')
plt.legend()
plt.xlabel('AGE')
plt.ylabel('Luminosity: triple-alpha')
plt.xlim(14.90,14.95)
plt.ylim(0,1e28);

# %%
plt.plot(dp['log(L/Lsun)'].values,dp['Luminosity: triple-alpha'],'b-',label='Original')
plt.plot(dpLHS16['log(L/Lsun)'],dpLHS16['Luminosity: triple-alpha'],'r--',label='LHS16')
#plt.plot(dpLdeBoer17['AGE'],dpLdeBoer17['Luminosity: triple-alpha'],'y--',label='LdeBoer17')
#plt.plot(dpLHS16LdeBoer17['AGE'],dpLHS16LdeBoer17['Luminosity: triple-alpha'],'g-',label='Both')
plt.legend()
plt.xlabel('log(L/Lsun)')
plt.ylabel('Luminosity: triple-alpha')
plt.ylim(0,1e28);
